# %%
# Importing all dependencies & installing each package needed for analysis

import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import requests
import lxml
from pandas.io.json import json_normalize

# !pip install folium
import folium

# !pip install scikit-learn
import sklearn
from sklearn.cluster import KMeans

# %%
# This capstone project explores the regions around Pittsburgh, PA and, by utilizing Foursquare, an interactive map is created that will assist in pinpointing existing areas of competition to be used by prospective owners of a conceptual pizzeria/bar restaurant (i.e. where Foursquare data shows pizza restaurants and bars as the top venues).  The url's below provide the information for all zip codes and geographical data within Allegheny County, PA:

url = 'http://www.ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?FIPS=42003'
find_lat_long_url = 'https://public.opendatasoft.com/api/records/1.0/search/?dataset=us-zip-code-latitude-and-longitude&q=zip%3D{zip}'

# Using pandas read_html, pulled all zip codes corresponding to (unique) cities/neighborhoods within Allegheny County, PA (Pittsburgh suburbs)

pittsburgh_postal = pd.read_html(url)
df = pittsburgh_postal[2]
df2 = pittsburgh_postal[3]
df3 = pittsburgh_postal[4]
df4 = pittsburgh_postal[5]

df_pittsburgh = pd.concat([df, df2, df3, df4], axis = 0, ignore_index = True)

df_pittsburgh = df_pittsburgh.drop(['County'], axis = 1) 
df_pittsburgh.insert(2, "Latitude", 0.0)
df_pittsburgh.insert(3, "Longitude", 0.0)
df_geo_pittsburgh = df_pittsburgh


# Created a for-loop to incorporate both latitude/longitude from the open data API for all unique neighborhoods in Allegheny County, PA

for index, row in df_pittsburgh.iterrows():
    zipcode = row['Zip Code']
    current_lat_long_url = find_lat_long_url.format(zip = zipcode)
    response = requests.get(current_lat_long_url)
    records_json = response.json()['records'] 
    has_items = bool(records_json)
    if not has_items:
        continue
    records_json = records_json[0]
    fields_json = records_json['fields']
    latitude = fields_json['latitude']
    longitude = fields_json['longitude']
    df_geo_pittsburgh.at[index, 'Latitude'] = latitude
    df_geo_pittsburgh.at[index, 'Longitude'] = longitude
    
df_geo_pittsburgh_final = df_geo_pittsburgh.drop_duplicates(subset = ["Latitude"])
df_geo_pittsburgh_final = df_geo_pittsburgh_final.drop_duplicates(subset = ["City"])
df_geo_pittsburgh_final = df_geo_pittsburgh_final.drop_duplicates(subset = ["Zip Code"])
df_geo_pittsburgh_final = df_geo_pittsburgh_final[df_geo_pittsburgh_final.Latitude != 0]
df_geo_pittsburgh_final.tail(50)
# Out:
#      Zip Code               City   Latitude  Longitude
# 51      15116           Glenshaw  40.533806  -79.96303
# 52      15120          Homestead  40.395336  -79.90635
# 56      15122         Pittsburgh  40.366177  -79.89418
# 59      15126           Imperial  40.454423  -80.26324
# 61      15129            Library  40.289752  -80.00756
# 64      15131         McKeesport  40.341469  -79.81105
# 69      15135             Boston  40.306819  -79.81450
# 71      15136       McKees Rocks  40.471618  -80.07695
# 72      15137   North Versailles  40.380219  -79.81017
# 73      15139            Oakmont  40.519518  -79.83762
# 74      15140        Monroeville  40.405768  -79.77643
# 76      15142             Presto  40.379549  -80.12451
# 77      15143          Edgeworth  40.561091  -80.15554
# 79      15144         Springdale  40.543053  -79.78223
# 80      15145       Turtle Creek  40.408218  -79.82339
# 82      15147             Verona  40.498218  -79.83426
# 83      15148               Wall  40.394268  -79.80286
# 85      15201            Arsenal  40.471468  -79.95726
# 87      15202            Bellvue  40.502918  -80.07040
# 93      15203             Carson  40.426211  -79.97826
# 95      15204            Corliss  40.455118  -80.06008
# 97      15205            Crafton  40.436618  -80.07289
# 99      15206       East Liberty  40.468968  -79.91863
# 101     15207          Hazelwood  40.399355  -79.93414
# 103     15208           Homewood  40.455168  -79.89709
# 105     15209           Millvale  40.492618  -79.97458
# 107     15210          Mt Oliver  40.409219  -79.98948
# 110     15211   Mount Washington  40.428369  -80.01269
# 113     15212          Allegheny  40.460669  -80.01144
# 115     15213            Oakland  40.443269  -79.95487
# 117     15214        Observatory  40.479469  -80.01150
# 119     15215          Aspinwall  40.497701  -79.91570
# 122     15216        South Hills  40.400319  -80.03566
# 124     15217      Squirrel Hill  40.430919  -79.92569
# 129     15220             Wabash  40.430822  -80.04453
# 134     15223               Etna  40.503768  -79.95164
# 136     15224         Bloomfield  40.463463  -79.94612
# 138     15225     Neville Island  40.513778  -80.13571
# 140     15226          Brookline  40.394002  -80.01655
# 142     15227          Brentwood  40.377869  -79.97516
# 144     15228      Mount Lebanon  40.372802  -80.04480
# 150     15232          Shadyside  40.454018  -79.93250
# 152     15233            Kilbuck  40.455919  -80.02604
# 154     15234     Castle Shannon  40.369619  -80.01831
# 156     15235         Penn Hills  40.459518  -79.83277
# 158     15236      Caste Village  40.342869  -79.97929
# 162     15237           Mcknight  40.552768  -80.03227
# 164     15238            Blawnox  40.518701  -79.86744
# 169     15241  Upper Saint Clair  40.329619  -80.07364
# 173     15243         Cedarhurst  40.372669  -80.07120

# %%
#Creating a folium map of Pittsburgh, which includes all unique towns designated by postal code in Allegheny Country (& later consolidated):
map_pittsburgh = folium.Map(location=[40.463, -80.011], zoom_start = 10)

for lat, lng, label in zip(df_geo_pittsburgh['Latitude'], df_geo_pittsburgh['Longitude'], df_geo_pittsburgh['City']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pittsburgh)  
    
map_pittsburgh
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_96066100dbd34c90a84d91b05d5aedab%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_96066100dbd34c90a84d91b05d5aedab%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_96066100dbd34c90a84d91b05d5aedab%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_96066100dbd34c90a84d91b05d5aedab%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.463%2C%20-80.011%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#The following code provides all necessary access to Foursquare and allows for proper grouping of all Pittsburgh area venues to be grouped:
CLIENT_ID = '4YGCUSWECQXY35RF1PRFH2BLG4CKUEJ5AQC1V42GINDNQ11C'
CLIENT_SECRET = 'BOILTJDRWTGF1YNYUIPFWIDZZB0PE4Q1QSQZ0CMDCPFDOZDB'
VERSION = '20180604'
LIMIT = 100 

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):            
        #API Request to Foursquare
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)

        #GET request
        results = requests.get(url).json()["response"]
        has_response = bool(results)
        
        if not has_response:
            continue

        groups_json = results['groups']
        has_items = bool(groups_json)
        if not has_items:
            continue
        items = groups_json[0]['items']

        if not bool(items):
            continue

        #Will return all relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in items])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

#Checking the first (5) returned Pittsburgh neighborhood venues:
pittsburgh_venues = getNearbyVenues(names = df_geo_pittsburgh['City'], latitudes = df_geo_pittsburgh['Latitude'], longitudes = df_geo_pittsburgh['Longitude'])

pittsburgh_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Bairdford              40.630894               -79.88057
# 1    Bairdford              40.630894               -79.88057
# 2    Bairdford              40.630894               -79.88057
# 3   Bakerstown              40.652311               -79.93303
# 4   Bakerstown              40.652311               -79.93303
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0      United States Postal Service       40.632229       -79.879144
# 1                    Bairdford Park       40.629222       -79.877576
# 2                            Brunch       40.632473       -79.876480
# 3  Richland Township Community Park       40.655932       -79.930172
# 4      United States Postal Service       40.650729       -79.935447
#
#    Venue Category
# 0     Post Office
# 1            Park
# 2  Breakfast Spot
# 3      Playground
# 4     Post Office

# %%
#Next, utilizing one-hot coding to effectively demonstrate the distribution of venues per neighborhood (to allow for later clustering)
pittsburgh_venues.groupby('Neighborhood')

pittsburgh_onehot = pd.get_dummies(pittsburgh_venues[['Venue Category']], prefix="", prefix_sep="")
pittsburgh_onehot['Neighborhood'] = pittsburgh_venues['Neighborhood']

fixed_columns = [pittsburgh_onehot.columns[-1]] + list(pittsburgh_onehot.columns[:-1])
pittsburgh_onehot = pittsburgh_onehot[fixed_columns]

pittsburgh_grouped = pittsburgh_onehot.groupby('Neighborhood').mean().reset_index()
pittsburgh_grouped

#Keeping only the neighborhoods which contain a statistically significant amount of venues within the Foursquare database (again allowing for later clustering); this encompasses a total of 33 neighborhoods.  Allowing too many rural areas, which contain only 1-4 venues will tend to skew grouping.  This was determined to be the most accurate way to consolidate the area, while maximizing the existing Foursquare venue data

counts = np.count_nonzero(pittsburgh_grouped, axis=1)

array_indexes_to_drop = []

for index, count in enumerate(counts):
    if count < 8:
        array_indexes_to_drop.append(index)

pittsburgh_grouped.drop(array_indexes_to_drop, inplace = True)
pittsburgh_grouped
# Out:
#          Neighborhood       ATM  American Restaurant    Arcade  Art Gallery  \
# 2             Arsenal  0.000000             0.021277  0.021277     0.000000
# 10        Bethel Park  0.000000             0.000000  0.000000     0.000000
# 12         Bloomfield  0.000000             0.000000  0.000000     0.042553
# 18        Bridgeville  0.000000             0.181818  0.000000     0.000000
# 19          Brookline  0.000000             0.000000  0.000000     0.000000
# 23           Carnegie  0.000000             0.000000  0.000000     0.000000
# 24             Carson  0.000000             0.081081  0.000000     0.000000
# 25      Caste Village  0.000000             0.000000  0.000000     0.000000
# 26     Castle Shannon  0.000000             0.000000  0.000000     0.000000
# 32            Crafton  0.000000             0.000000  0.000000     0.000000
# 52         Heidelberg  0.000000             0.000000  0.000000     0.000000
# 54           Homewood  0.000000             0.000000  0.000000     0.000000
# 62       McKees Rocks  0.000000             0.000000  0.000000     0.000000
# 63         McKeesport  0.000000             0.035714  0.000000     0.000000
# 66        Monroeville  0.000000             0.000000  0.000000     0.000000
# 71       Mount Oliver  0.000000             0.125000  0.000000     0.000000
# 72   Mount Washington  0.000000             0.055556  0.000000     0.000000
# 73          Mt Oliver  0.000000             0.125000  0.000000     0.000000
# 74      Mt Washington  0.000000             0.055556  0.000000     0.000000
# 81            Oakland  0.000000             0.015152  0.000000     0.000000
# 82            Oakmont  0.000000             0.125000  0.000000     0.000000
# 86         Pittsburgh  0.001508             0.022624  0.003017     0.006033
# 87     Pleasant Hills  0.000000             0.000000  0.000000     0.000000
# 93          Shadyside  0.000000             0.000000  0.000000     0.000000
# 95        South Hills  0.000000             0.000000  0.000000     0.000000
# 97         Springdale  0.000000             0.000000  0.000000     0.000000
# 98      Squirrel Hill  0.000000             0.000000  0.000000     0.000000
# 100         Swissvale  0.000000             0.030303  0.000000     0.000000
# 102      Turtle Creek  0.000000             0.000000  0.000000     0.000000
# 110      West Mifflin  0.000000             0.000000  0.000000     0.000000
# 111         West View  0.000000             0.000000  0.000000     0.000000
# 112           Wexford  0.000000             0.000000  0.000000     0.000000
# 114         White Oak  0.000000             0.083333  0.000000     0.000000
#
#      Art Museum  Arts & Crafts Store  Asian Restaurant  Astrologer  \
# 2      0.000000             0.042553          0.000000         0.0
# 10     0.000000             0.000000          0.000000         0.0
# 12     0.000000             0.000000          0.000000         0.0
# 18     0.000000             0.000000          0.000000         0.0
# 19     0.000000             0.000000          0.000000         0.0
# 23     0.000000             0.000000          0.000000         0.0
# 24     0.000000             0.000000          0.054054         0.0
# 25     0.000000             0.000000          0.000000         0.0
# 26     0.000000             0.000000          0.000000         0.0
# 32     0.000000             0.000000          0.000000         0.0
# 52     0.000000             0.000000          0.000000         0.0
# 54     0.000000             0.000000          0.000000         0.0
# 62     0.000000             0.000000          0.000000         0.0
# 63     0.000000             0.000000          0.000000         0.0
# 66     0.000000             0.000000          0.000000         0.0
# 71     0.000000             0.000000          0.000000         0.0
# 72     0.000000             0.000000          0.000000         0.0
# 73     0.000000             0.000000          0.000000         0.0
# 74     0.000000             0.000000          0.000000         0.0
# 81     0.015152             0.000000          0.030303         0.0
# 82     0.000000             0.000000          0.000000         0.0
# 86     0.003017             0.007541          0.012066         0.0
# 87     0.000000             0.000000          0.000000         0.0
# 93     0.000000             0.020408          0.040816         0.0
# 95     0.000000             0.000000          0.000000         0.0
# 97     0.000000             0.000000          0.000000         0.0
# 98     0.000000             0.041667          0.000000         0.0
# 100    0.000000             0.000000          0.000000         0.0
# 102    0.000000             0.000000          0.000000         0.1
# 110    0.000000             0.000000          0.000000         0.0
# 111    0.000000             0.000000          0.030303         0.0
# 112    0.000000             0.000000          0.000000         0.0
# 114    0.000000             0.000000          0.000000         0.0
#
#      Athletics & Sports  ...  Turkish Restaurant  \
# 2              0.000000  ...            0.000000
# 10             0.000000  ...            0.000000
# 12             0.000000  ...            0.000000
# 18             0.000000  ...            0.000000
# 19             0.000000  ...            0.000000
# 23             0.000000  ...            0.000000
# 24             0.000000  ...            0.000000
# 25             0.000000  ...            0.000000
# 26             0.000000  ...            0.000000
# 32             0.000000  ...            0.000000
# 52             0.000000  ...            0.000000
# 54             0.000000  ...            0.000000
# 62             0.000000  ...            0.000000
# 63             0.000000  ...            0.000000
# 66             0.000000  ...            0.000000
# 71             0.000000  ...            0.000000
# 72             0.000000  ...            0.000000
# 73             0.000000  ...            0.000000
# 74             0.000000  ...            0.000000
# 81             0.000000  ...            0.015152
# 82             0.000000  ...            0.000000
# 86             0.003017  ...            0.003017
# 87             0.000000  ...            0.000000
# 93             0.000000  ...            0.020408
# 95             0.000000  ...            0.000000
# 97             0.000000  ...            0.000000
# 98             0.000000  ...            0.000000
# 100            0.000000  ...            0.000000
# 102            0.000000  ...            0.000000
# 110            0.000000  ...            0.000000
# 111            0.000000  ...            0.000000
# 112            0.000000  ...            0.000000
# 114            0.000000  ...            0.000000
#
#      Vegetarian / Vegan Restaurant  Video Game Store  Video Store  \
# 2                         0.000000          0.000000     0.021277
# 10                        0.000000          0.000000     0.000000
# 12                        0.021277          0.000000     0.021277
# 18                        0.000000          0.000000     0.000000
# 19                        0.000000          0.000000     0.000000
# 23                        0.000000          0.000000     0.000000
# 24                        0.000000          0.000000     0.000000
# 25                        0.000000          0.000000     0.000000
# 26                        0.000000          0.000000     0.000000
# 32                        0.000000          0.000000     0.000000
# 52                        0.000000          0.000000     0.000000
# 54                        0.000000          0.000000     0.000000
# 62                        0.000000          0.000000     0.000000
# 63                        0.000000          0.000000     0.000000
# 66                        0.000000          0.000000     0.000000
# 71                        0.000000          0.000000     0.125000
# 72                        0.000000          0.000000     0.000000
# 73                        0.000000          0.000000     0.125000
# 74                        0.000000          0.000000     0.000000
# 81                        0.015152          0.015152     0.000000
# 82                        0.000000          0.000000     0.000000
# 86                        0.004525          0.006033     0.009050
# 87                        0.000000          0.000000     0.000000
# 93                        0.000000          0.000000     0.000000
# 95                        0.000000          0.000000     0.000000
# 97                        0.000000          0.000000     0.000000
# 98                        0.041667          0.000000     0.000000
# 100                       0.000000          0.030303     0.030303
# 102                       0.000000          0.000000     0.000000
# 110                       0.000000          0.000000     0.000000
# 111                       0.000000          0.000000     0.030303
# 112                       0.000000          0.000000     0.000000
# 114                       0.000000          0.000000     0.000000
#
#      Vietnamese Restaurant  Warehouse Store  Water Park  Wings Joint  \
# 2                 0.021277         0.000000    0.000000     0.000000
# 10                0.000000         0.000000    0.000000     0.000000
# 12                0.000000         0.000000    0.000000     0.000000
# 18                0.000000         0.000000    0.000000     0.000000
# 19                0.000000         0.000000    0.000000     0.000000
# 23                0.000000         0.000000    0.000000     0.000000
# 24                0.000000         0.000000    0.000000     0.000000
# 25                0.000000         0.000000    0.000000     0.000000
# 26                0.000000         0.000000    0.000000     0.000000
# 32                0.000000         0.000000    0.000000     0.000000
# 52                0.000000         0.000000    0.000000     0.000000
# 54                0.000000         0.000000    0.000000     0.000000
# 62                0.000000         0.000000    0.000000     0.000000
# 63                0.000000         0.000000    0.000000     0.000000
# 66                0.000000         0.000000    0.000000     0.000000
# 71                0.000000         0.000000    0.000000     0.000000
# 72                0.000000         0.000000    0.000000     0.000000
# 73                0.000000         0.000000    0.000000     0.000000
# 74                0.000000         0.000000    0.000000     0.000000
# 81                0.000000         0.000000    0.000000     0.000000
# 82                0.000000         0.000000    0.000000     0.000000
# 86                0.003017         0.001508    0.001508     0.003017
# 87                0.000000         0.000000    0.000000     0.000000
# 93                0.000000         0.000000    0.000000     0.000000
# 95                0.000000         0.000000    0.000000     0.000000
# 97                0.000000         0.000000    0.000000     0.000000
# 98                0.041667         0.000000    0.000000     0.000000
# 100               0.000000         0.000000    0.000000     0.000000
# 102               0.000000         0.000000    0.000000     0.000000
# 110               0.000000         0.000000    0.000000     0.000000
# 111               0.000000         0.000000    0.000000     0.000000
# 112               0.000000         0.000000    0.000000     0.000000
# 114               0.000000         0.000000    0.000000     0.000000
#
#      Women's Store  Yoga Studio
# 2         0.021277     0.000000
# 10        0.000000     0.000000
# 12        0.000000     0.000000
# 18        0.000000     0.000000
# 19        0.000000     0.000000
# 23        0.000000     0.000000
# 24        0.000000     0.000000
# 25        0.000000     0.000000
# 26        0.000000     0.000000
# 32        0.000000     0.000000
# 52        0.000000     0.000000
# 54        0.000000     0.000000
# 62        0.000000     0.000000
# 63        0.000000     0.000000
# 66        0.000000     0.000000
# 71        0.000000     0.000000
# 72        0.000000     0.000000
# 73        0.000000     0.000000
# 74        0.000000     0.000000
# 81        0.000000     0.000000
# 82        0.000000     0.125000
# 86        0.006033     0.003017
# 87        0.000000     0.000000
# 93        0.020408     0.020408
# 95        0.000000     0.000000
# 97        0.000000     0.000000
# 98        0.000000     0.000000
# 100       0.030303     0.000000
# 102       0.000000     0.000000
# 110       0.000000     0.000000
# 111       0.000000     0.000000
# 112       0.000000     0.000000
# 114       0.000000     0.000000
#
# [33 rows x 222 columns]

# %%
#Executed the following code to have a glance at the top venues per major neighborhoods within scope
num_top_venues = 5

for hood in pittsburgh_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = pittsburgh_grouped[pittsburgh_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Arsenal----
#                  venue  freq
# 0                  Bar  0.06
# 1       Sandwich Place  0.06
# 2           Taco Place  0.04
# 3  Arts & Crafts Store  0.04
# 4          Karaoke Bar  0.04
#
#
# ----Bethel Park----
#             venue  freq
# 0  Breakfast Spot  0.11
# 1  Sandwich Place  0.11
# 2             Bar  0.11
# 3             Gym  0.11
# 4     Pizza Place  0.11
#
#
# ----Bloomfield----
#              venue  freq
# 0      Pizza Place  0.06
# 1      Coffee Shop  0.06
# 2    Grocery Store  0.04
# 3              Bar  0.04
# 4  Thai Restaurant  0.04
#
#
# ----Bridgeville----
#                  venue  freq
# 0          Gas Station  0.18
# 1  American Restaurant  0.18
# 2       Sandwich Place  0.09
# 3   Chinese Restaurant  0.09
# 4          Coffee Shop  0.09
#
#
# ----Brookline----
#                 venue  freq
# 0         Pizza Place  0.17
# 1  Italian Restaurant  0.08
# 2        Liquor Store  0.08
# 3                 Spa  0.08
# 4       Grocery Store  0.08
#
#
# ----Carnegie----
#                 venue  freq
# 0  Italian Restaurant  0.11
# 1             Library  0.11
# 2                 Bar  0.11
# 3                Bank  0.11
# 4   Food & Drink Shop  0.11
#
#
# ----Carson----
#                  venue  freq
# 0                  Bar  0.11
# 1  American Restaurant  0.08
# 2     Asian Restaurant  0.05
# 3     Sushi Restaurant  0.05
# 4      Thai Restaurant  0.05
#
#
# ----Caste Village----
#                 venue  freq
# 0      Baseball Field  0.14
# 1  Chinese Restaurant  0.14
# 2                 Bar  0.14
# 3              Bakery  0.14
# 4   Convenience Store  0.14
#
#
# ----Castle Shannon----
#                 venue  freq
# 0        Dessert Shop  0.14
# 1  Light Rail Station  0.14
# 2         Coffee Shop  0.14
# 3       Train Station  0.14
# 4              Bakery  0.14
#
#
# ----Crafton----
#                 venue  freq
# 0         Pizza Place  0.12
# 1            Pharmacy  0.12
# 2      Discount Store  0.06
# 3         Supermarket  0.06
# 4  Chinese Restaurant  0.06
#
#
# ----Heidelberg----
#                 venue  freq
# 0  Italian Restaurant  0.11
# 1             Library  0.11
# 2                 Bar  0.11
# 3                Bank  0.11
# 4   Food & Drink Shop  0.11
#
#
# ----Homewood----
#          venue  freq
# 0         Food  0.11
# 1  Bus Station  0.11
# 2         Café  0.11
# 3  Music Venue  0.11
# 4          Bar  0.11
#
#
# ----McKees Rocks----
#                  venue  freq
# 0          Pizza Place  0.20
# 1       Breakfast Spot  0.13
# 2  Indie Movie Theater  0.07
# 3               Bakery  0.07
# 4             Pharmacy  0.07
#
#
# ----McKeesport----
#            venue  freq
# 0            Bar  0.11
# 1  Moving Target  0.07
# 2    Pizza Place  0.07
# 3  Boat or Ferry  0.07
# 4         Tunnel  0.07
#
#
# ----Monroeville----
#                         venue  freq
# 0                        Park  0.22
# 1                        Pool  0.11
# 2  Construction & Landscaping  0.11
# 3                         Bar  0.11
# 4                      Bakery  0.11
#
#
# ----Mount Oliver----
#                   venue  freq
# 0     Fish & Chips Shop  0.12
# 1     Convenience Store  0.12
# 2  Fast Food Restaurant  0.12
# 3   American Restaurant  0.12
# 4   Fried Chicken Joint  0.12
#
#
# ----Mount Washington----
#             venue  freq
# 0  Baseball Field  0.11
# 1           Diner  0.11
# 2        Pharmacy  0.06
# 3  Sandwich Place  0.06
# 4             Bar  0.06
#
#
# ----Mt Oliver----
#                   venue  freq
# 0     Fish & Chips Shop  0.12
# 1     Convenience Store  0.12
# 2  Fast Food Restaurant  0.12
# 3   American Restaurant  0.12
# 4   Fried Chicken Joint  0.12
#
#
# ----Mt Washington----
#             venue  freq
# 0  Baseball Field  0.11
# 1           Diner  0.11
# 2        Pharmacy  0.06
# 3  Sandwich Place  0.06
# 4             Bar  0.06
#
#
# ----Oakland----
#                 venue  freq
# 0         Pizza Place  0.08
# 1         Coffee Shop  0.06
# 2  Chinese Restaurant  0.03
# 3          Bagel Shop  0.03
# 4        Burger Joint  0.03
#
#
# ----Oakmont----
#                  venue  freq
# 0          Yoga Studio  0.12
# 1               Bakery  0.12
# 2  American Restaurant  0.12
# 3       Ice Cream Shop  0.12
# 4           Hobby Shop  0.12
#
#
# ----Pittsburgh----
#             venue  freq
# 0             Bar  0.05
# 1     Pizza Place  0.04
# 2     Coffee Shop  0.03
# 3  Sandwich Place  0.03
# 4          Tunnel  0.02
#
#
# ----Pleasant Hills----
#                 venue  freq
# 0      Baseball Field  0.14
# 1  Chinese Restaurant  0.14
# 2                 Bar  0.14
# 3              Bakery  0.14
# 4   Convenience Store  0.14
#
#
# ----Shadyside----
#               venue  freq
# 0    Clothing Store  0.06
# 1       Coffee Shop  0.06
# 2  Asian Restaurant  0.04
# 3               Gym  0.04
# 4            Bakery  0.04
#
#
# ----South Hills----
#                 venue  freq
# 0         Pizza Place  0.25
# 1       Deli / Bodega  0.12
# 2       Movie Theater  0.12
# 3  Light Rail Station  0.12
# 4               Plaza  0.12
#
#
# ----Springdale----
#                 venue  freq
# 0  Salon / Barbershop   0.2
# 1         Pizza Place   0.2
# 2      Discount Store   0.1
# 3      General Travel   0.1
# 4          Soup Place   0.1
#
#
# ----Squirrel Hill----
#                  venue  freq
# 0          Pizza Place  0.12
# 1          Coffee Shop  0.08
# 2  Dumpling Restaurant  0.04
# 3           Bagel Shop  0.04
# 4             Tea Room  0.04
#
#
# ----Swissvale----
#                   venue  freq
# 0     Convenience Store  0.09
# 1             Pet Store  0.06
# 2                  Bank  0.06
# 3  Fast Food Restaurant  0.06
# 4        Discount Store  0.06
#
#
# ----Turtle Creek----
#                 venue  freq
# 0         Pizza Place   0.2
# 1  Italian Restaurant   0.1
# 2                Bank   0.1
# 3   Convenience Store   0.1
# 4            Pharmacy   0.1
#
#
# ----West Mifflin----
#                venue  freq
# 0                Bar  0.17
# 1  Convenience Store  0.08
# 2      Grocery Store  0.08
# 3     Baseball Field  0.08
# 4        Pizza Place  0.08
#
#
# ----West View----
#                   venue  freq
# 0                  Bank  0.09
# 1        Discount Store  0.09
# 2  Fast Food Restaurant  0.06
# 3    Chinese Restaurant  0.06
# 4           Pizza Place  0.06
#
#
# ----Wexford----
#                   venue  freq
# 0  Fast Food Restaurant  0.14
# 1         Deli / Bodega  0.14
# 2                  Bank  0.14
# 3         Moving Target  0.14
# 4                Bakery  0.14
#
#
# ----White Oak----
#                   venue  freq
# 0        Discount Store  0.08
# 1        Sandwich Place  0.08
# 2          Optical Shop  0.08
# 3    Miscellaneous Shop  0.08
# 4  Gym / Fitness Center  0.08

# %%
#Defining the following function in order to allow the venues to be sorted in ascending top venue order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

#Subsequently, setting up a separate df to display the top 10 venues/neighborhood (see following table)
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

#Columns according to n-th top venues:
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

#New df arranging by most common venues per neighborhood - thus starting to more easily see where pizza restaurants and bars are concentrated:
pittsburgh_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
pittsburgh_neighborhoods_venues_sorted['Neighborhood'] = pittsburgh_grouped['Neighborhood']

for ind in np.arange(pittsburgh_grouped.shape[0]):
   pittsburgh_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(pittsburgh_grouped.iloc[ind, :], num_top_venues)

pittsburgh_neighborhoods_venues_sorted.head(30)
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 2             Arsenal                   Bar        Sandwich Place
# 10        Bethel Park        Breakfast Spot        Sandwich Place
# 12         Bloomfield           Pizza Place           Coffee Shop
# 18        Bridgeville           Gas Station   American Restaurant
# 19          Brookline           Pizza Place    Italian Restaurant
# 23           Carnegie    Italian Restaurant               Library
# 24             Carson                   Bar   American Restaurant
# 25      Caste Village        Baseball Field    Chinese Restaurant
# 26     Castle Shannon          Dessert Shop    Light Rail Station
# 32            Crafton           Pizza Place              Pharmacy
# 52         Heidelberg    Italian Restaurant               Library
# 54           Homewood                  Food           Bus Station
# 62       McKees Rocks           Pizza Place        Breakfast Spot
# 63         McKeesport                   Bar         Moving Target
# 66        Monroeville                  Park                  Pool
# 71       Mount Oliver     Fish & Chips Shop     Convenience Store
# 72   Mount Washington        Baseball Field                 Diner
# 73          Mt Oliver     Fish & Chips Shop     Convenience Store
# 74      Mt Washington        Baseball Field                 Diner
# 81            Oakland           Pizza Place           Coffee Shop
# 82            Oakmont           Yoga Studio                Bakery
# 86         Pittsburgh                   Bar           Pizza Place
# 87     Pleasant Hills        Baseball Field    Chinese Restaurant
# 93          Shadyside        Clothing Store           Coffee Shop
# 95        South Hills           Pizza Place         Deli / Bodega
# 97         Springdale    Salon / Barbershop           Pizza Place
# 98      Squirrel Hill           Pizza Place           Coffee Shop
# 100         Swissvale     Convenience Store             Pet Store
# 102      Turtle Creek           Pizza Place    Italian Restaurant
# 110      West Mifflin                   Bar     Convenience Store
#
#           3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2                    Taco Place   Arts & Crafts Store           Karaoke Bar
# 10                          Bar                   Gym           Pizza Place
# 12                Grocery Store                   Bar       Thai Restaurant
# 18               Sandwich Place    Chinese Restaurant           Coffee Shop
# 19                 Liquor Store                   Spa         Grocery Store
# 23                          Bar                  Bank     Food & Drink Shop
# 24             Asian Restaurant      Sushi Restaurant       Thai Restaurant
# 25                          Bar                Bakery     Convenience Store
# 26                  Coffee Shop         Train Station                Bakery
# 32               Discount Store           Supermarket    Chinese Restaurant
# 52                          Bar                  Bank     Food & Drink Shop
# 54                         Café           Music Venue                   Bar
# 62          Indie Movie Theater                Bakery              Pharmacy
# 63                  Pizza Place         Boat or Ferry                Tunnel
# 66   Construction & Landscaping                   Bar                Bakery
# 71         Fast Food Restaurant   American Restaurant   Fried Chicken Joint
# 72                     Pharmacy        Sandwich Place                   Bar
# 73         Fast Food Restaurant   American Restaurant   Fried Chicken Joint
# 74                     Pharmacy        Sandwich Place                   Bar
# 81           Chinese Restaurant            Bagel Shop          Burger Joint
# 82          American Restaurant        Ice Cream Shop            Hobby Shop
# 86                  Coffee Shop        Sandwich Place   American Restaurant
# 87                          Bar                Bakery     Convenience Store
# 93             Asian Restaurant                   Gym                Bakery
# 95                Movie Theater    Light Rail Station                 Plaza
# 97               Discount Store        General Travel            Soup Place
# 98          Dumpling Restaurant            Bagel Shop              Tea Room
# 100                        Bank  Fast Food Restaurant        Discount Store
# 102                        Bank     Convenience Store              Pharmacy
# 110               Grocery Store        Baseball Field           Pizza Place
#
#     6th Most Common Venue       7th Most Common Venue 8th Most Common Venue  \
# 2     Indie Movie Theater                 Bus Station            Sports Bar
# 10           Home Service          Mexican Restaurant           Beer Garden
# 12            Art Gallery                   Bookstore        Sandwich Place
# 18     Mexican Restaurant       Performing Arts Venue              Pharmacy
# 19              Bike Shop           Convenience Store                Bakery
# 23            Pizza Place          Miscellaneous Shop               Theater
# 24         Ice Cream Shop                         Pub          Burger Joint
# 25          Grocery Store                  Laundromat     Other Repair Shop
# 26             Playground                         Bar            Print Shop
# 32          Grocery Store         Fried Chicken Joint            Shoe Store
# 52            Pizza Place          Miscellaneous Shop               Theater
# 54                   Bank  Construction & Landscaping     Convenience Store
# 62                   Café                         Spa                   Bar
# 63              Disc Golf                Optical Shop           Coffee Shop
# 66                    Pub                 Pizza Place           Flower Shop
# 71            Video Store              Hardware Store           Pizza Place
# 72                   Bank                      Bakery        Breakfast Spot
# 73            Video Store              Hardware Store           Pizza Place
# 74                   Bank                      Bakery        Breakfast Spot
# 81      Indian Restaurant              Cosmetics Shop                Museum
# 82                    Spa                        Bank    Italian Restaurant
# 86          Moving Target          Italian Restaurant         Boat or Ferry
# 87          Grocery Store                  Laundromat     Other Repair Shop
# 93    Japanese Restaurant          Salon / Barbershop                   Bar
# 95                   Park                         Bar             Pet Store
# 97     Chinese Restaurant  Construction & Landscaping                   Bar
# 98        Thai Restaurant            Toy / Game Store  Marijuana Dispensary
# 100           Music Store              Cosmetics Shop              Pharmacy
# 102            Smoke Shop               Garden Center        Discount Store
# 110                Bakery                      Tunnel         Boat or Ferry
#
#              9th Most Common Venue    10th Most Common Venue
# 2                      Coffee Shop                       Gym
# 10                  Ice Cream Shop         Other Repair Shop
# 12         New American Restaurant              Burger Joint
# 18                           Hotel               Post Office
# 19                          Lounge  Mediterranean Restaurant
# 23                       Gift Shop      Other Great Outdoors
# 24                    Dance Studio                  Boutique
# 25            Other Great Outdoors     Outdoors & Recreation
# 26                             Pub              Noodle House
# 32                             Bar                      Bank
# 52                       Gift Shop      Other Great Outdoors
# 54            Gym / Fitness Center     Performing Arts Venue
# 62                            Bank                     Plaza
# 63            Gym / Fitness Center            Shipping Store
# 66   Paper / Office Supplies Store                       ATM
# 71           Performing Arts Venue                      Park
# 72                  Scenic Lookout               Pizza Place
# 73           Performing Arts Venue                      Park
# 74                  Scenic Lookout               Pizza Place
# 81         New American Restaurant                  Dive Bar
# 82                Video Game Store                Public Art
# 86                          Tunnel                    Bakery
# 87            Other Great Outdoors     Outdoors & Recreation
# 93                         Gay Bar        Mexican Restaurant
# 95                    Noodle House              Optical Shop
# 97                     Post Office                      Pool
# 98                      Sports Bar          Greek Restaurant
# 100              Mobile Phone Shop           Supplement Shop
# 102                     Astrologer                   Library
# 110                  Moving Target        Chinese Restaurant

# %%
#Setting up to divide the neighborhoods into 6 clusters; optimized amount to filter out the heaviest concentration of pizzerias/bars:
kclusters = 6
pittsburgh_grouped_clustering = pittsburgh_grouped.drop('Neighborhood', 1)

#Implementing K-means clustering fit (and installing/importing sklearn package):
#!pip install scikit-learn
import sklearn
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(pittsburgh_grouped_clustering)

#Adding Clustering Labels 0 through 5 -- later setting up corresponding colored markers
pittsburgh_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
pittsburgh_merged = df_geo_pittsburgh_final

#Merging both df's to add latitude/longitude for each neighborhood from Foursquare to add to the subsequent map
pittsburgh_merged = pittsburgh_merged.join(pittsburgh_neighborhoods_venues_sorted.set_index('Neighborhood'), on='City')
pittsburgh_merged.dropna(axis=0, inplace=True)

# %%
#Initiating a folium map in order to add the final clustering results, based on top venues
map_clusters = folium.Map(location=[40.463, -80.011], zoom_start=10)

#Cluster coloring scheme:
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#Successfully added colored markers to the map alongside cluster numbering, based on respective shared/top venues (Note: chose index-5 to obtain red markers for Label 4, which best emphasizes the desired variable - i.e. locale of pizzeria/bar centric areas)
markers_colors = []
for lat, lon, poi, cluster in zip(pittsburgh_merged['Latitude'], pittsburgh_merged['Longitude'], pittsburgh_merged['City'], pittsburgh_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    index = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[index-5],
        fill=True,
        fill_color=rainbow[index-5],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0069e87fb0714799bd4b78079efa7000%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0069e87fb0714799bd4b78079efa7000%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0069e87fb0714799bd4b78079efa7000%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0069e87fb0714799bd4b78079efa7000%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.463%2C%20-80.011%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#Looking at the map, the following most common venues define the clustering #'s:

#Label 0 = Italian/Library
pittsburgh_merged.loc[pittsburgh_merged['Cluster Labels'] == 0, pittsburgh_merged.columns[[1] + list(range(5, pittsburgh_merged.shape[1]))]]
# Out:
#         City 1st Most Common Venue 2nd Most Common Venue  \
# 45  Carnegie    Italian Restaurant               Library
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 45                   Bar                  Bank     Food & Drink Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 45           Pizza Place    Miscellaneous Shop               Theater
#
#    9th Most Common Venue 10th Most Common Venue
# 45             Gift Shop   Other Great Outdoors

# %%
#Label 1 = Gas Station/Yoga/American
pittsburgh_merged.loc[pittsburgh_merged['Cluster Labels'] == 1, pittsburgh_merged.columns[[1] + list(range(5, pittsburgh_merged.shape[1]))]]
# Out:
#            City 1st Most Common Venue 2nd Most Common Venue  \
# 4   Bridgeville           Gas Station   American Restaurant
# 73      Oakmont           Yoga Studio                Bakery
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 4         Sandwich Place    Chinese Restaurant           Coffee Shop
# 73   American Restaurant        Ice Cream Shop            Hobby Shop
#
#    6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 4     Mexican Restaurant  Performing Arts Venue              Pharmacy
# 73                   Spa                   Bank    Italian Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 4                  Hotel            Post Office
# 73      Video Game Store             Public Art

# %%
#Label 2 = Fish & Chips/Convenience Store/Fast Food
pittsburgh_merged.loc[pittsburgh_merged['Cluster Labels'] == 2, pittsburgh_merged.columns[[1] + list(range(5, pittsburgh_merged.shape[1]))]]
# Out:
#           City 1st Most Common Venue 2nd Most Common Venue  \
# 107  Mt Oliver     Fish & Chips Shop     Convenience Store
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 107  Fast Food Restaurant   American Restaurant   Fried Chicken Joint
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 107           Video Store        Hardware Store           Pizza Place
#
#      9th Most Common Venue 10th Most Common Venue
# 107  Performing Arts Venue                   Park

# %%
#Label 3 = Baseball Field/Chinese Restaurant
pittsburgh_merged.loc[pittsburgh_merged['Cluster Labels'] == 3, pittsburgh_merged.columns[[1] + list(range(5, pittsburgh_merged.shape[1]))]]
# Out:
#               City 1st Most Common Venue 2nd Most Common Venue  \
# 158  Caste Village        Baseball Field    Chinese Restaurant
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 158                   Bar                Bakery     Convenience Store
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 158         Grocery Store            Laundromat     Other Repair Shop
#
#     9th Most Common Venue 10th Most Common Venue
# 158  Other Great Outdoors  Outdoors & Recreation

# %%
#Label 4 = Pizzeria/Bar/Coffee Shop -- It is here within the red-dotted neighborhoods where, by far, the most pizzerias/bars exist
pittsburgh_merged.loc[pittsburgh_merged['Cluster Labels'] == 4, pittsburgh_merged.columns[[1] + list(range(5, pittsburgh_merged.shape[1]))]]
# Out:
#                  City 1st Most Common Venue 2nd Most Common Venue  \
# 37            Wexford  Fast Food Restaurant         Deli / Bodega
# 42        Bethel Park        Breakfast Spot        Sandwich Place
# 56         Pittsburgh                   Bar           Pizza Place
# 64         McKeesport                   Bar         Moving Target
# 71       McKees Rocks           Pizza Place        Breakfast Spot
# 74        Monroeville                  Park                  Pool
# 79         Springdale    Salon / Barbershop           Pizza Place
# 80       Turtle Creek           Pizza Place    Italian Restaurant
# 85            Arsenal                   Bar        Sandwich Place
# 93             Carson                   Bar   American Restaurant
# 97            Crafton           Pizza Place              Pharmacy
# 103          Homewood                  Food           Bus Station
# 110  Mount Washington        Baseball Field                 Diner
# 115           Oakland           Pizza Place           Coffee Shop
# 122       South Hills           Pizza Place         Deli / Bodega
# 124     Squirrel Hill           Pizza Place           Coffee Shop
# 136        Bloomfield           Pizza Place           Coffee Shop
# 140         Brookline           Pizza Place    Italian Restaurant
# 150         Shadyside        Clothing Store           Coffee Shop
#
#           3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 37                         Bank         Moving Target                Bakery
# 42                          Bar                   Gym           Pizza Place
# 56                  Coffee Shop        Sandwich Place   American Restaurant
# 64                  Pizza Place         Boat or Ferry                Tunnel
# 71          Indie Movie Theater                Bakery              Pharmacy
# 74   Construction & Landscaping                   Bar                Bakery
# 79               Discount Store        General Travel            Soup Place
# 80                         Bank     Convenience Store              Pharmacy
# 85                   Taco Place   Arts & Crafts Store           Karaoke Bar
# 93             Asian Restaurant      Sushi Restaurant       Thai Restaurant
# 97               Discount Store           Supermarket    Chinese Restaurant
# 103                        Café           Music Venue                   Bar
# 110                    Pharmacy        Sandwich Place                   Bar
# 115          Chinese Restaurant            Bagel Shop          Burger Joint
# 122               Movie Theater    Light Rail Station                 Plaza
# 124         Dumpling Restaurant            Bagel Shop              Tea Room
# 136               Grocery Store                   Bar       Thai Restaurant
# 140                Liquor Store                   Spa         Grocery Store
# 150            Asian Restaurant                   Gym                Bakery
#
#     6th Most Common Venue       7th Most Common Venue 8th Most Common Venue  \
# 37             Taco Place              Cosmetics Shop                   ATM
# 42           Home Service          Mexican Restaurant           Beer Garden
# 56          Moving Target          Italian Restaurant         Boat or Ferry
# 64              Disc Golf                Optical Shop           Coffee Shop
# 71                   Café                         Spa                   Bar
# 74                    Pub                 Pizza Place           Flower Shop
# 79     Chinese Restaurant  Construction & Landscaping                   Bar
# 80             Smoke Shop               Garden Center        Discount Store
# 85    Indie Movie Theater                 Bus Station            Sports Bar
# 93         Ice Cream Shop                         Pub          Burger Joint
# 97          Grocery Store         Fried Chicken Joint            Shoe Store
# 103                  Bank  Construction & Landscaping     Convenience Store
# 110                  Bank                      Bakery        Breakfast Spot
# 115     Indian Restaurant              Cosmetics Shop                Museum
# 122                  Park                         Bar             Pet Store
# 124       Thai Restaurant            Toy / Game Store  Marijuana Dispensary
# 136           Art Gallery                   Bookstore        Sandwich Place
# 140             Bike Shop           Convenience Store                Bakery
# 150   Japanese Restaurant          Salon / Barbershop                   Bar
#
#              9th Most Common Venue    10th Most Common Venue
# 37   Paper / Office Supplies Store     Performing Arts Venue
# 42                  Ice Cream Shop         Other Repair Shop
# 56                          Tunnel                    Bakery
# 64            Gym / Fitness Center            Shipping Store
# 71                            Bank                     Plaza
# 74   Paper / Office Supplies Store                       ATM
# 79                     Post Office                      Pool
# 80                      Astrologer                   Library
# 85                     Coffee Shop                       Gym
# 93                    Dance Studio                  Boutique
# 97                             Bar                      Bank
# 103           Gym / Fitness Center     Performing Arts Venue
# 110                 Scenic Lookout               Pizza Place
# 115        New American Restaurant                  Dive Bar
# 122                   Noodle House              Optical Shop
# 124                     Sports Bar          Greek Restaurant
# 136        New American Restaurant              Burger Joint
# 140                         Lounge  Mediterranean Restaurant
# 150                        Gay Bar        Mexican Restaurant

# %%
#Label 5 = Dessert/Trolley Stations
pittsburgh_merged.loc[pittsburgh_merged['Cluster Labels'] == 5, pittsburgh_merged.columns[[1] + list(range(5, pittsburgh_merged.shape[1]))]]
# Out:
#                City 1st Most Common Venue 2nd Most Common Venue  \
# 154  Castle Shannon          Dessert Shop    Light Rail Station
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 154           Coffee Shop         Train Station                Bakery
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 154            Playground                   Bar            Print Shop
#
#     9th Most Common Venue 10th Most Common Venue
# 154                   Pub           Noodle House
